# %%
# %cd '~/Dropbox/fjs6/Journal/ideolog/Dimwit/examples/dataScienceLondon/data/'
# Out:
# /Users/fjs6/Dropbox/fjs6/Journal/ideolog/Dimwit/examples/dataScienceLondon/data

# %%
import numpy as np
from pandas import *
import pandas
import math
import random
from sklearn import preprocessing
from sklearn import svm
from sklearn.svm import SVC
from sklearn.cross_validation import StratifiedKFold
from sklearn.grid_search import GridSearchCV
from sklearn.decomposition import PCA

import sys
sys.path.append('/Users/fjs6/Dropbox/fjs6/Journal/ideolog/Dimwit')

# %%
tr_data = read_csv('train.csv', header=None)
test_data = read_csv('test.csv', header=None)
data = concat([tr_data, test_data], ignore_index=True)

# %%
gt_data = read_csv('trainLabels.csv', header=None)

# %%
def laundromat(model, X, Y, XUniverse, max_acc, PCUT = 0.95):
    # train
    model.fit(X, Y)
    
    # evaluate
    p = model.predict(X_CV)
    count = 0.0
    M_CV = len(Y_CV)
    for i in range(M_CV):
        if p[i]==Y_CV[i]:
            count+=1
    acc = 100*count/M_CV
    print 'score on CV', acc, 'support vectors', model.support_vectors_.shape[0]
    if acc < max_acc:
        print 'breaking out'
        return [X, Y, XUniverse, max_acc, True]
    
    # go deeper
    prob = model.predict_proba(XUniverse)
    M_U, N_U = XUniverse.shape
    X1 = X.copy()
    Y1 = Y.copy()
    X_Rest = np.zeros((1, N_U))

    for i in range(M_U):
        y = np.argmax(prob[i,:])
        p = np.max(prob[i,:])
        record = XUniverse[i:i+1,:]
        if p > PCUT:
            X1 = np.append(X1, record, axis=0)
            Y1 = np.append(Y1, y)
        else:
            X_Rest = np.vstack([X_Rest, record])
    X_Rest = np.delete(X_Rest, 0, 0)
    return [X1, Y1, X_Rest, acc, False]

# %%
def heatmap(grid, C_range, g_range):
    print("The best classifier is: ", grid.best_estimator_)
    print 'best score', grid.best_score_
    score_dict = grid.grid_scores_
    scores = [x[1] for x in score_dict]
    scores = np.array(scores).reshape(len(C_range), len(g_range))

    plt.figure(figsize=(8, 6))
    plt.subplots_adjust(left=0.05, right=0.95, bottom=0.15, top=0.95)
    plt.imshow(scores, interpolation='nearest', cmap=plt.cm.spectral)
    plt.xlabel('g')
    plt.ylabel('C')
    plt.colorbar()
    plt.xticks(np.arange(len(g_range)), g_range, rotation=45)
    plt.yticks(np.arange(len(C_range)), C_range)
    plt.show()

# %% [markdown]
# #### 1st Filter : Preselecting features with highest power

# %%
features = list([3, 5, 6, 7, 12, 14, 15, 16, 18, 20, 23, 25, 28, 29, 30, 32, 34, 36, 38, 39])
#features =  list([3, 4, 6, 7, 11, 12, 13, 14, 18, 19, 22, 28, 29, 32, 34, 36, 38, 39]) # my past svm cycling best
x_all = np.array(data.ix[:,features])
y_all = np.ravel(gt_data)

# %%
a = [14,12,29,6,36,39,7,4,28,19,22,18,38,3, 32, 34, 13, 11]
a.sort()
print a
# Out:
# [3, 4, 6, 7, 11, 12, 13, 14, 18, 19, 22, 28, 29, 32, 34, 36, 38, 39]

# %% [markdown]
# #### 2nd Filter: Reducing dimmensionality up to 97.48%

# %%
from sklearn.decomposition import RandomizedPCA
pca = RandomizedPCA(n_components=12, whiten=True)
pca.fit(x_all)
x_all = pca.transform(x_all)

# %%
x_all.shape
# Out:
# (10000, 12)

# %% [markdown]
# #### Dividing initial training data to create mini cross validation set

# %%
limit_cv = 300

X_CV = x_all[0:limit_cv,:]
Y_CV = y_all[0:limit_cv]

X_TR = x_all[limit_cv:,:]
Y_TR = y_all[limit_cv:]

# %% [markdown]
# #### Optimizing hyperparams on initial training set

# %%
C_range = [10000000.]
g_range = np.arange(0.05, .5, 0.02)
#g_range = [1.]
limit_tr = 1000-limit_cv

param_grid = dict(gamma=g_range, C=C_range)
clfo = svm.SVC(kernel='rbf', cache_size=1000, probability=True)

cv = StratifiedKFold(Y_TR[0:limit_tr], n_folds=7)
grid = GridSearchCV(clfo, param_grid=param_grid, cv=cv, verbose=5)

grid.fit(X_TR[0:limit_tr,:], Y_TR[0:limit_tr])
print("The best classifier is: ", grid.best_estimator_)
print 'best score', grid.best_score_
score_dict = grid.grid_scores_
scores = [x[1] for x in score_dict]
scores = np.array(scores).reshape(len(C_range), len(g_range))

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.15, top=0.95)
plt.imshow(scores, interpolation='nearest', cmap=plt.cm.spectral)
plt.xlabel('g')
plt.ylabel('C')
plt.colorbar()
plt.xticks(np.arange(len(g_range)), g_range, rotation=45)
plt.yticks(np.arange(len(C_range)), C_range)
plt.show()

# %% [markdown]
# #### SVM Recursive to inflate new training set

# %%
limit_tr = 1000-limit_cv

total_acc = 97.8
fu2 = False

while fu2 == False:
    print '-'*20
    clf = svm.SVC(kernel='rbf', cache_size=1000, probability=True, C=10000000., gamma=0.22, shrinking=True)
    [A,B,C, acc, fu] = laundromat(clf, X_TR[0:limit_tr,:], Y_TR[0:limit_tr], X_TR[limit_tr:,:], 0.0, PCUT = 0.95)
    clf = svm.SVC(kernel='rbf', cache_size=1000, probability=True, C=10000000., gamma=0.275)
    fu = False
    acc = 0.9
    past_c, past_acc = 0., 0.
    while fu == False:
        [A,B,C, acc, fu] = laundromat(clf, A, B, C, acc, PCUT = 0.99)
        if past_c == C.shape[0] and past_acc == acc:
            fu = True
        else:
            past_c = C.shape[0]
            past_acc = acc
    if acc > total_acc:
        total_acc = acc
        fu2 = True
# Out:
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1896
# score on CV
#  96.6666666667 support vectors 2070
# score on CV
#  97.3333333333 support vectors 2181
# score on CV
#  97.3333333333 support vectors 2208
# score on CV
#  97.3333333333 support vectors 2252
# score on CV
#  97.3333333333 support vectors 2256
# score on CV
#  97.3333333333 support vectors 2272
# score on CV
#  97.3333333333 support vectors 2272
# score on CV
#  97.3333333333 support vectors 2285
# score on CV
#  97.3333333333 support vectors 2293
# score on CV
#  97.3333333333 support vectors 2292
# score on CV
#  97.3333333333 support vectors 2294
# score on CV
#  97.3333333333 support vectors 2300
# score on CV
#  97.3333333333 support vectors 2312
# score on CV
#  97.3333333333 support vectors 2308
# score on CV
#  97.3333333333 support vectors 2315
# score on CV
#  97.3333333333 support vectors 2315
# score on CV
#  97.3333333333 support vectors 2317
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1907
# score on CV
#  97.0 support vectors 2091
# score on CV
#  97.3333333333 support vectors 2196
# score on CV
#  97.3333333333 support vectors 2246
# score on CV
#  97.3333333333 support vectors 2282
# score on CV
#  97.3333333333 support vectors 2287
# score on CV
#  97.3333333333 support vectors 2288
# score on CV
#  97.6666666667 support vectors 2295
# score on CV
#  97.6666666667 support vectors 2306
# score on CV
#  97.6666666667 support vectors 2313
# score on CV
#  97.6666666667 support vectors 2315
# score on CV
#  97.6666666667 support vectors 2310
# score on CV
#  97.3333333333 support vectors 2308
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1784
# score on CV
#  96.6666666667 support vectors 1960
# score on CV
#  96.6666666667 support vectors 2140
# score on CV
#  96.6666666667 support vectors 2188
# score on CV
#  97.0 support vectors 2228
# score on CV
#  97.0 support vectors 2261
# score on CV
#  97.3333333333 support vectors 2293
# score on CV
#  97.3333333333 support vectors 2317
# score on CV
#  97.3333333333 support vectors 2331
# score on CV
#  97.3333333333 support vectors 2332
# score on CV
#  97.3333333333 support vectors 2329
# score on CV
#  97.3333333333 support vectors 2331
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1879
# score on CV
#  96.6666666667 support vectors 2047
# score on CV
#  97.0 support vectors 2171
# score on CV
#  97.0 support vectors 2203
# score on CV
#  97.3333333333 support vectors 2258
# score on CV
#  97.3333333333 support vectors 2281
# score on CV
#  97.3333333333 support vectors 2271
# score on CV
#  97.3333333333 support vectors 2291
# score on CV
#  97.3333333333 support vectors 2310
# score on CV
#  97.3333333333 support vectors 2320
# score on CV
#  97.3333333333 support vectors 2323
# score on CV
#  97.3333333333 support vectors 2322
# score on CV
#  97.3333333333 support vectors 2323
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1831
# score on CV
#  96.3333333333 support vectors 2021
# score on CV
#  96.6666666667 support vectors 2148
# score on CV
#  97.0 support vectors 2184
# score on CV
#  97.0 support vectors 2218
# score on CV
#  97.0 support vectors 2247
# score on CV
#  97.3333333333 support vectors 2258
# score on CV
#  97.3333333333 support vectors 2286
# score on CV
#  97.3333333333 support vectors 2291
# score on CV
#  97.3333333333 support vectors 2287
# score on CV
#  97.3333333333 support vectors 2287
# score on CV
#  97.0 support vectors 2307
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1877
# score on CV
#  96.6666666667 support vectors 2023
# score on CV
#  97.3333333333 support vectors 2153
# score on CV
#  97.0 support vectors 2223
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1808
# score on CV
#  96.3333333333 support vectors 1998
# score on CV
#  96.6666666667 support vectors 2159
# score on CV
#  97.0 support vectors 2206
# score on CV
#  96.6666666667 support vectors 2214
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1848
# score on CV
#  96.6666666667 support vectors 2036
# score on CV
#  97.3333333333 support vectors 2164
# score on CV
#  97.0 support vectors 2226
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1872
# score on CV
#  96.6666666667 support vectors 2063
# score on CV
#  97.0 support vectors 2164
# score on CV
#  97.3333333333 support vectors 2207
# score on CV
#  97.0 support vectors 2243
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1781
# score on CV
#  96.6666666667 support vectors 1934
# score on CV
#  97.0 support vectors 2090
# score on CV
#  97.3333333333 support vectors 2143
# score on CV
#  97.0 support vectors 2210
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1868
# score on CV
#  97.0 support vectors 2060
# score on CV
#  97.3333333333 support vectors 2175
# score on CV
#  97.0 support vectors 2227
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1776
# score on CV
#  96.6666666667 support vectors 1987
# score on CV
#  97.3333333333 support vectors 2109
# score on CV
#  97.0 support vectors 2188
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1860
# score on CV
#  96.3333333333 support vectors 2034
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1764
# score on CV
#  96.6666666667 support vectors 1952
# score on CV
#  96.6666666667 support vectors 2147
# score on CV
#  96.6666666667 support vectors 2236
# score on CV
#  96.6666666667 support vectors 2262
# score on CV
#  96.6666666667 support vectors 2261
# score on CV
#  96.6666666667 support vectors 2276
# score on CV
#  97.0 support vectors 2299
# score on CV
#  97.0 support vectors 2302
# score on CV
#  97.0 support vectors 2292
# score on CV
#  97.0 support vectors 2300
# score on CV
#  97.3333333333 support vectors 2309
# score on CV
#  97.0 support vectors 2298
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1846
# score on CV
#  96.3333333333 support vectors 2003
# score on CV
#  97.0 support vectors 2165
# score on CV
#  97.0 support vectors 2192
# score on CV
#  97.0 support vectors 2241
# score on CV
#  97.3333333333 support vectors 2280
# score on CV
#  97.3333333333 support vectors 2294
# score on CV
#  97.3333333333 support vectors 2300
# score on CV
#  97.3333333333 support vectors 2325
# score on CV
#  97.3333333333 support vectors 2327
# score on CV
#  97.3333333333 support vectors 2337
# score on CV
#  97.0 support vectors 2333
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1813
# score on CV
#  96.6666666667 support vectors 2001
# score on CV
#  97.0 support vectors 2154
# score on CV
#  97.0 support vectors 2203
# score on CV
#  97.0 support vectors 2249
# score on CV
#  97.0 support vectors 2250
# score on CV
#  97.0 support vectors 2274
# score on CV
#  97.0 support vectors 2287
# score on CV
#  97.0 support vectors 2285
# score on CV
#  97.0 support vectors 2289
# score on CV
#  97.0 support vectors 2289
# score on CV
#  97.0 support vectors 2305
# score on CV
#  97.0 support vectors 2295
# score on CV
#  97.0 support vectors 2295
# score on CV
#  97.0 support vectors 2302
# score on CV
#  97.0 support vectors 2300
# score on CV
#  97.0 support vectors 2300
# score on CV
#  97.0 support vectors 2303
# score on CV
#  97.0 support vectors 2307
# score on CV
#  97.0 support vectors 2306
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1819
# score on CV
#  96.6666666667 support vectors 2002
# score on CV
#  97.3333333333 support vectors 2147
# score on CV
#  97.0 support vectors 2205
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1829
# score on CV
#  96.6666666667 support vectors 2013
# score on CV
#  96.6666666667 support vectors 2150
# score on CV
#  97.0 support vectors 2210
# score on CV
#  97.0 support vectors 2251
# score on CV
#  97.0 support vectors 2263
# score on CV
#  97.0 support vectors 2291
# score on CV
#  96.6666666667 support vectors 2308
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1887
# score on CV
#  96.6666666667 support vectors 2074
# score on CV
#  97.3333333333 support vectors 2179
# score on CV
#  97.0 support vectors 2246
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1746
# score on CV
#  97.0 support vectors 1887
# score on CV
#  97.0 support vectors 2068
# score on CV
#  97.3333333333 support vectors 2176
# score on CV
#  97.3333333333 support vectors 2221
# score on CV
#  97.0 support vectors 2262
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1869
# score on CV
#  96.6666666667 support vectors 2027
# score on CV
#  97.3333333333 support vectors 2156
# score on CV
#  97.0 support vectors 2217
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1804
# score on CV
#  96.6666666667 support vectors 1987
# score on CV
#  96.6666666667 support vectors 2148
# score on CV
#  97.3333333333 support vectors 2198
# score on CV
#  97.0 support vectors 2250
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1776
# score on CV
#  96.6666666667 support vectors 1985
# score on CV
#  97.3333333333 support vectors 2125
# score on CV
#  97.0 support vectors 2204
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1865
# score on CV
#  96.3333333333 support vectors 2036
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1848
# score on CV
#  96.6666666667 support vectors 2002
# score on CV
#  97.3333333333 support vectors 2142
# score on CV
#  97.3333333333 support vectors 2201
# score on CV
#  97.0 support vectors 2222
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1866
# score on CV
#  96.6666666667 support vectors 1998
# score on CV
#  97.0 support vectors 2140
# score on CV
#  96.6666666667 support vectors 2234
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1765
# score on CV
#  96.6666666667 support vectors 1951
# score on CV
#  97.0 support vectors 2125
# score on CV
#  97.0 support vectors 2178
# score on CV
#  97.0 support vectors 2229
# score on CV
#  97.0 support vectors 2258
# score on CV
#  97.0 support vectors 2277
# score on CV
#  97.3333333333 support vectors 2300
# score on CV
#  97.3333333333 support vectors 2302
# score on CV
#  97.3333333333 support vectors 2315
# score on CV
#  97.0 support vectors 2302
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1866
# score on CV
#  96.6666666667 support vectors 2053
# score on CV
#  97.3333333333 support vectors 2184
# score on CV
#  97.0 support vectors 2228
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1886
# score on CV
#  96.6666666667 support vectors 2062
# score on CV
#  97.0 support vectors 2167
# score on CV
#  97.0 support vectors 2222
# score on CV
#  97.0 support vectors 2240
# score on CV
#  97.0 support vectors 2266
# score on CV
#  97.0 support vectors 2255
# score on CV
#  97.0 support vectors 2272
# score on CV
#  97.0 support vectors 2275
# score on CV
#  97.0 support vectors 2282
# score on CV
#  97.0 support vectors 2287
# score on CV
#  97.0 support vectors 2287
# score on CV
#  97.0 support vectors 2288
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1884
# score on CV
#  96.6666666667 support vectors 2061
# score on CV
#  97.3333333333 support vectors 2167
# score on CV
#  97.0 support vectors 2202
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1841
# score on CV
#  96.3333333333 support vectors 1988
# score on CV
#  96.3333333333 support vectors 2126
# score on CV
#  96.6666666667 support vectors 2144
# score on CV
#  96.6666666667 support vectors 2207
# score on CV
#  96.6666666667 support vectors 2251
# score on CV
#  97.0 support vectors 2268
# score on CV
#  97.0 support vectors 2292
# score on CV
#  97.0 support vectors 2296
# score on CV
#  97.0 support vectors 2305
# score on CV
#  97.0 support vectors 2298
# score on CV
#  97.0 support vectors 2287
# score on CV
#  97.0 support vectors 2305
# score on CV
#  97.0 support vectors 2304
# score on CV
#  97.0 support vectors 2298
# score on CV
#  97.0 support vectors 2291
# score on CV
#  97.0 support vectors 2296
# score on CV
#  97.0 support vectors 2295
# score on CV
#  97.0 support vectors 2302
# score on CV
#  97.0 support vectors 2303
# score on CV
#  97.0 support vectors 2300
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1782
# score on CV
#  97.0 support vectors 1972
# score on CV
#  96.3333333333 support vectors 2121
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1813
# score on CV
#  96.6666666667 support vectors 2014
# score on CV
#  96.6666666667 support vectors 2153
# score on CV
#  96.6666666667 support vectors 2205
# score on CV
#  97.0 support vectors 2244
# score on CV
#  97.0 support vectors 2286
# score on CV
#  97.0 support vectors 2292
# score on CV
#  97.0 support vectors 2308
# score on CV
#  97.0 support vectors 2308
# score on CV
#  97.0 support vectors 2312
# score on CV
#  97.0 support vectors 2314
# score on CV
#  97.0 support vectors 2317
# score on CV
#  97.0 support vectors 2315
# score on CV
#  97.0 support vectors 2323
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1777
# score on CV
#  96.6666666667 support vectors 1955
# score on CV
#  96.6666666667 support vectors 2121
# score on CV
#  96.6666666667 support vectors 2199
# score on CV
#  96.6666666667 support vectors 2240
# score on CV
#  96.6666666667 support vectors 2268
# score on CV
#  96.6666666667 support vectors 2288
# score on CV
#  96.6666666667 support vectors 2292
# score on CV
#  96.6666666667 support vectors 2306
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1902
# score on CV
#  97.0 support vectors 2099
# score on CV
#  97.3333333333 support vectors 2191
# score on CV
#  97.0 support vectors 2261
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1812
# score on CV
#  96.6666666667 support vectors 2010
# score on CV
#  97.0 support vectors 2141
# score on CV
#  96.6666666667 support vectors 2201
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1809
# score on CV
#  96.6666666667 support vectors 1992
# score on CV
#  97.0 support vectors 2139
# score on CV
#  96.6666666667 support vectors 2202
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1815
# score on CV
#  96.6666666667 support vectors 2009
# score on CV
#  97.0 support vectors 2124
# score on CV
#  97.0 support vectors 2168
# score on CV
#  97.0 support vectors 2255
# score on CV
#  97.3333333333 support vectors 2272
# score on CV
#  97.3333333333 support vectors 2285
# score on CV
#  97.3333333333 support vectors 2296
# score on CV
#  97.3333333333 support vectors 2290
# score on CV
#  97.3333333333 support vectors 2297
# score on CV
#  97.3333333333 support vectors 2301
# score on CV
#  97.3333333333 support vectors 2304
# score on CV
#  97.3333333333 support vectors 2311
# score on CV
#  97.3333333333 support vectors 2309
# score on CV
#  97.3333333333 support vectors 2317
# score on CV
#  97.3333333333 support vectors 2313
# score on CV
#  97.3333333333 support vectors 2316
# score on CV
#  97.3333333333 support vectors 2320
# score on CV
#  97.3333333333 support vectors 2322
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1805
# score on CV
#  96.6666666667 support vectors 2003
# score on CV
#  96.6666666667 support vectors 2131
# score on CV
#  97.0 support vectors 2185
# score on CV
#  97.0 support vectors 2211
# score on CV
#  97.0 support vectors 2249
# score on CV
#  97.0 support vectors 2255
# score on CV
#  97.0 support vectors 2249
# score on CV
#  97.0 support vectors 2251
# score on CV
#  97.0 support vectors 2262
# score on CV
#  97.0 support vectors 2277
# score on CV
#  97.0 support vectors 2286
# score on CV
#  97.0 support vectors 2286
# score on CV
#  97.0 support vectors 2284
# score on CV
#  97.0 support vectors 2293
# score on CV
#  97.0 support vectors 2294
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1841
# score on CV
#  96.3333333333 support vectors 2019
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1780
# score on CV
#  96.6666666667 support vectors 1939
# score on CV
#  97.0 support vectors 2106
# score on CV
#  97.0 support vectors 2157
# score on CV
#  96.6666666667 support vectors 2205
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1818
# score on CV
#  96.6666666667 support vectors 1998
# score on CV
#  96.6666666667 support vectors 2148
# score on CV
#  97.0 support vectors 2222
# score on CV
#  97.0 support vectors 2255
# score on CV
#  97.0 support vectors 2276
# score on CV
#  97.0 support vectors 2291
# score on CV
#  97.0 support vectors 2290
# score on CV
#  97.0 support vectors 2302
# score on CV
#  97.0 support vectors 2302
# score on CV
#  97.0 support vectors 2306
# score on CV
#  97.0 support vectors 2311
# score on CV
#  97.0 support vectors 2308
# score on CV
#  97.0 support vectors 2304
# score on CV
#  97.0 support vectors 2310
# score on CV
#  97.0 support vectors 2319
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1777
# score on CV
#  97.0 support vectors 1985
# score on CV
#  96.6666666667 support vectors 2148
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1788
# score on CV
#  96.6666666667 support vectors 2004
# score on CV
#  97.3333333333 support vectors 2156
# score on CV
#  97.0 support vectors 2217
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1784
# score on CV
#  96.6666666667 support vectors 1950
# score on CV
#  97.3333333333 support vectors 2137
# score on CV
#  97.0 support vectors 2191
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1808
# score on CV
#  96.6666666667 support vectors 1979
# score on CV
#  96.6666666667 support vectors 2142
# score on CV
#  97.0 support vectors 2192
# score on CV
#  97.0 support vectors 2235
# score on CV
#  97.0 support vectors 2252
# score on CV
#  97.0 support vectors 2253
# score on CV
#  97.0 support vectors 2260
# score on CV
#  97.0 support vectors 2264
# score on CV
#  97.0 support vectors 2265
# score on CV
#  97.0 support vectors 2278
# score on CV
#  97.0 support vectors 2284
# score on CV
#  97.0 support vectors 2286
# score on CV
#  97.0 support vectors 2284
# score on CV
#  97.0 support vectors 2286
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1751
# score on CV
#  96.6666666667 support vectors 1941
# score on CV
#  97.0 support vectors 2114
# score on CV
#  97.0 support vectors 2165
# score on CV
#  97.0 support vectors 2227
# score on CV
#  97.0 support vectors 2246
# score on CV
#  97.0 support vectors 2268
# score on CV
#  97.0 support vectors 2287
# score on CV
#  97.0 support vectors 2294
# score on CV
#  97.0 support vectors 2311
# score on CV
#  97.0 support vectors 2316
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1745
# score on CV
#  96.6666666667 support vectors 1939
# score on CV
#  96.6666666667 support vectors 2091
# score on CV
#  96.6666666667 support vectors 2170
# score on CV
#  96.6666666667 support vectors 2228
# score on CV
#  96.6666666667 support vectors 2275
# score on CV
#  96.6666666667 support vectors 2291
# score on CV
#  96.6666666667 support vectors 2296
# score on CV
#  96.6666666667 support vectors 2295
# score on CV
#  96.6666666667 support vectors 2304
# score on CV
#  96.6666666667 support vectors 2303
# score on CV
#  97.0 support vectors 2306
# score on CV
#  97.3333333333 support vectors 2306
# score on CV
#  97.3333333333 support vectors 2315
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  95.3333333333 support vectors 1796
# score on CV
#  96.6666666667 support vectors 1969
# score on CV
#  96.3333333333 support vectors 2124
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1854
# score on CV
#  96.3333333333 support vectors 2007
# score on CV
#  96.6666666667 support vectors 2130
# score on CV
#  97.0 support vectors 2215
# score on CV
#  97.0 support vectors 2246
# score on CV
#  97.3333333333 support vectors 2268
# score on CV
#  97.3333333333 support vectors 2290
# score on CV
#  97.3333333333 support vectors 2309
# score on CV
#  97.3333333333 support vectors 2313
# score on CV
#  97.3333333333 support vectors 2329
# score on CV
#  97.3333333333 support vectors 2326
# score on CV
#  97.3333333333 support vectors 2319
# score on CV
#  97.3333333333 support vectors 2322
# score on CV
#  97.3333333333 support vectors 2328
# score on CV
#  97.3333333333 support vectors 2327
# score on CV
#  97.3333333333 support vectors 2332
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1801
# score on CV
#  96.6666666667 support vectors 1982
# score on CV
#  96.6666666667 support vectors 2125
# score on CV
#  97.0 support vectors 2188
# score on CV
#  97.0 support vectors 2260
# score on CV
#  97.3333333333 support vectors 2283
# score on CV
#  97.3333333333 support vectors 2307
# score on CV
#  97.3333333333 support vectors 2309
# score on CV
#  97.3333333333 support vectors 2323
# score on CV
#  97.3333333333 support vectors 2315
# score on CV
#  97.3333333333 support vectors 2323
# score on CV
#  97.3333333333 support vectors 2309
# score on CV
#  97.3333333333 support vectors 2311
# score on CV
#  97.3333333333 support vectors 2322
# score on CV
#  97.3333333333 support vectors 2319
# score on CV
#  97.3333333333 support vectors 2321
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  95.3333333333 support vectors 1792
# score on CV
#  96.6666666667 support vectors 1981
# score on CV
#  97.3333333333 support vectors 2132
# score on CV
#  97.0 support vectors 2187
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  95.6666666667 support vectors 1774
# score on CV
#  96.6666666667 support vectors 1919
# score on CV
#  97.0 support vectors 2095
# score on CV
#  97.3333333333 support vectors 2182
# score on CV
#  97.3333333333 support vectors 2225
# score on CV
#  97.0 support vectors 2263
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1844
# score on CV
#  96.3333333333 support vectors 2022
# score on CV
#  97.0 support vectors 2146
# score on CV
#  97.0 support vectors 2185
# score on CV
#  97.0 support vectors 2224
# score on CV
#  97.0 support vectors 2240
# score on CV
#  97.0 support vectors 2260
# score on CV
#  97.0 support vectors 2261
# score on CV
#  96.6666666667 support vectors 2274
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1851
# score on CV
#  96.6666666667 support vectors 2040
# score on CV
#  97.3333333333 support vectors 2172
# score on CV
#  97.0 support vectors 2229
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1819
# score on CV
#  96.6666666667 support vectors 2005
# score on CV
#  97.0 support vectors 2170
# score on CV
#  97.0 support vectors 2224
# score on CV
#  97.0 support vectors 2264
# score on CV
#  97.0 support vectors 2294
# score on CV
#  97.0 support vectors 2308
# score on CV
#  97.0 support vectors 2323
# score on CV
#  97.0 support vectors 2315
# score on CV
#  97.0 support vectors 2329
# score on CV
#  97.0 support vectors 2319
# score on CV
#  97.0 support vectors 2326
# score on CV
#  97.0 support vectors 2323
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1822
# score on CV
#  96.6666666667 support vectors 2016
# score on CV
#  97.0 support vectors 2148
# score on CV
#  97.0 support vectors 2200
# score on CV
#  97.0 support vectors 2231
# score on CV
#  97.0 support vectors 2263
# score on CV
#  97.0 support vectors 2286
# score on CV
#  97.0 support vectors 2307
# score on CV
#  97.0 support vectors 2299
# score on CV
#  97.0 support vectors 2303
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1849
# score on CV
#  96.3333333333 support vectors 2030
# score on CV
#  97.0 support vectors 2172
# score on CV
#  96.6666666667 support vectors 2211
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1864
# score on CV
#  96.6666666667 support vectors 1997
# score on CV
#  97.0 support vectors 2150
# score on CV
#  97.0 support vectors 2188
# score on CV
#  97.0 support vectors 2238
# score on CV
#  97.3333333333 support vectors 2251
# score on CV
#  97.3333333333 support vectors 2261
# score on CV
#  97.3333333333 support vectors 2295
# score on CV
#  97.3333333333 support vectors 2319
# score on CV
#  97.3333333333 support vectors 2326
# score on CV
#  97.3333333333 support vectors 2323
# score on CV
#  97.3333333333 support vectors 2325
# score on CV
#  97.3333333333 support vectors 2330
# score on CV
#  97.3333333333 support vectors 2334
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1866
# score on CV
#  96.6666666667 support vectors 2059
# score on CV
#  97.3333333333 support vectors 2180
# score on CV
#  97.0 support vectors 2226
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1857
# score on CV
#  96.3333333333 support vectors 2049
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1808
# score on CV
#  96.6666666667 support vectors 2006
# score on CV
#  97.3333333333 support vectors 2146
# score on CV
#  97.0 support vectors 2210
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1885
# score on CV
#  96.6666666667 support vectors 2036
# score on CV
#  97.3333333333 support vectors 2170
# score on CV
#  97.0 support vectors 2208
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1884
# score on CV
#  96.6666666667 support vectors 2072
# score on CV
#  97.3333333333 support vectors 2176
# score on CV
#  97.0 support vectors 2241
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1788
# score on CV
#  96.6666666667 support vectors 1958
# score on CV
#  97.0 support vectors 2122
# score on CV
#  97.0 support vectors 2191
# score on CV
#  97.0 support vectors 2263
# score on CV
#  97.0 support vectors 2279
# score on CV
#  97.0 support vectors 2296
# score on CV
#  97.0 support vectors 2308
# score on CV
#  97.0 support vectors 2311
# score on CV
#  97.0 support vectors 2323
# score on CV
#  97.3333333333 support vectors 2326
# score on CV
#  97.3333333333 support vectors 2326
# score on CV
#  97.3333333333 support vectors 2327
# score on CV
#  97.3333333333 support vectors 2326
# score on CV
#  97.3333333333 support vectors 2325
# score on CV
#  97.3333333333 support vectors 2324
# score on CV
#  97.3333333333 support vectors 2325
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1819
# score on CV
#  96.6666666667 support vectors 1998
# score on CV
#  96.6666666667 support vectors 2138
# score on CV
#  97.0 support vectors 2199
# score on CV
#  97.0 support vectors 2217
# score on CV
#  97.0 support vectors 2229
# score on CV
#  97.0 support vectors 2247
# score on CV
#  97.0 support vectors 2262
# score on CV
#  97.0 support vectors 2268
# score on CV
#  97.0 support vectors 2259
# score on CV
#  97.0 support vectors 2266
# score on CV
#  97.0 support vectors 2266
# score on CV
#  97.0 support vectors 2269
# score on CV
#  97.0 support vectors 2275
# score on CV
#  97.0 support vectors 2286
# score on CV
#  97.0 support vectors 2273
# score on CV
#  97.0 support vectors 2271
# score on CV
#  97.0 support vectors 2275
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1789
# score on CV
#  96.6666666667 support vectors 1987
# score on CV
#  96.6666666667 support vectors 2146
# score on CV
#  97.0 support vectors 2212
# score on CV
#  97.3333333333 support vectors 2234
# score on CV
#  97.0 support vectors 2249
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1811
# score on CV
#  96.3333333333 support vectors 1995
# score on CV
#  96.6666666667 support vectors 2150
# score on CV
#  97.0 support vectors 2197
# score on CV
#  97.0 support vectors 2250
# score on CV
#  97.0 support vectors 2269
# score on CV
#  97.0 support vectors 2296
# score on CV
#  97.0 support vectors 2294
# score on CV
#  97.0 support vectors 2292
# score on CV
#  97.0 support vectors 2294
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1775
# score on CV
#  96.6666666667 support vectors 1970
# score on CV
#  97.3333333333 support vectors 2146
# score on CV
#  96.6666666667 support vectors 2231
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1834
# score on CV
#  96.3333333333 support vectors 2028
# score on CV
#  97.0 support vectors 2184
# score on CV
#  97.0 support vectors 2206
# score on CV
#  97.0 support vectors 2248
# score on CV
#  97.0 support vectors 2274
# score on CV
#  97.0 support vectors 2287
# score on CV
#  97.0 support vectors 2308
# score on CV
#  97.0 support vectors 2312
# score on CV
#  97.0 support vectors 2312
# score on CV
#  97.0 support vectors 2324
# score on CV
#  97.0 support vectors 2329
# score on CV
#  97.0 support vectors 2328
# score on CV
#  97.0 support vectors 2319
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1771
# score on CV
#  96.6666666667 support vectors 1957
# score on CV
#  97.0 support vectors 2116
# score on CV
#  97.0 support vectors 2225
# score on CV
#  96.6666666667 support vectors 2246
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1786
# score on CV
#  96.6666666667 support vectors 1971
# score on CV
#  97.3333333333 support vectors 2138
# score on CV
#  97.0 support vectors 2198
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1797
# score on CV
#  96.6666666667 support vectors 1992
# score on CV
#  97.3333333333 support vectors 2141
# score on CV
#  97.0 support vectors 2210
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1859
# score on CV
#  96.3333333333 support vectors 2038
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1848
# score on CV
#  96.3333333333 support vectors 2047
# score on CV
#  97.0 support vectors 2168
# score on CV
#  97.0 support vectors 2231
# score on CV
#  97.0 support vectors 2255
# score on CV
#  97.3333333333 support vectors 2277
# score on CV
#  97.3333333333 support vectors 2293
# score on CV
#  97.3333333333 support vectors 2289
# score on CV
#  97.3333333333 support vectors 2304
# score on CV
#  97.3333333333 support vectors 2305
# score on CV
#  97.3333333333 support vectors 2305
# score on CV
#  97.3333333333 support vectors 2296
# score on CV
#  97.3333333333 support vectors 2305
# score on CV
#  97.3333333333 support vectors 2313
# score on CV
#  97.3333333333 support vectors 2307
# score on CV
#  97.3333333333 support vectors 2317
# score on CV
#  97.3333333333 support vectors 2315
# score on CV
#  97.3333333333 support vectors 2322
# score on CV
#  97.3333333333 support vectors 2325
# score on CV
#  97.3333333333 support vectors 2315
# score on CV
#  97.3333333333 support vectors 2316
# score on CV
#  97.3333333333 support vectors 2314
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1822
# score on CV
#  96.3333333333 support vectors 2004
# score on CV
#  96.6666666667 support vectors 2157
# score on CV
#  96.6666666667 support vectors 2190
# score on CV
#  97.3333333333 support vectors 2215
# score on CV
#  97.3333333333 support vectors 2243
# score on CV
#  97.3333333333 support vectors 2274
# score on CV
#  97.3333333333 support vectors 2282
# score on CV
#  97.3333333333 support vectors 2281
# score on CV
#  97.3333333333 support vectors 2294
# score on CV
#  97.3333333333 support vectors 2293
# score on CV
#  97.3333333333 support vectors 2295
# score on CV
#  97.3333333333 support vectors 2285
# score on CV
#  97.3333333333 support vectors 2275
# score on CV
#  97.3333333333 support vectors 2282
# score on CV
#  97.3333333333 support vectors 2282
# score on CV
#  97.3333333333 support vectors 2293
# score on CV
#  97.3333333333 support vectors 2296
# score on CV
#  97.3333333333 support vectors 2297
# score on CV
#  97.3333333333 support vectors 2300
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1844
# score on CV
#  96.3333333333 support vectors 2012
# score on CV
#  97.0 support vectors 2157
# score on CV
#  96.6666666667 support vectors 2222
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1830
# score on CV
#  96.3333333333 support vectors 2013
# score on CV
#  96.6666666667 support vectors 2154
# score on CV
#  96.6666666667 support vectors 2229
# score on CV
#  97.0 support vectors 2258
# score on CV
#  97.0 support vectors 2282
# score on CV
#  97.0 support vectors 2290
# score on CV
#  97.0 support vectors 2292
# score on CV
#  96.6666666667 support vectors 2293
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1768
# score on CV
#  96.6666666667 support vectors 1939
# score on CV
#  96.6666666667 support vectors 2073
# score on CV
#  97.0 support vectors 2167
# score on CV
#  97.0 support vectors 2226
# score on CV
#  96.6666666667 support vectors 2265
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1779
# score on CV
#  96.6666666667 support vectors 1988
# score on CV
#  96.6666666667 support vectors 2172
# score on CV
#  96.6666666667 support vectors 2222
# score on CV
#  97.0 support vectors 2237
# score on CV
#  97.0 support vectors 2259
# score on CV
#  97.3333333333 support vectors 2270
# score on CV
#  97.3333333333 support vectors 2290
# score on CV
#  97.3333333333 support vectors 2288
# score on CV
#  97.3333333333 support vectors 2299
# score on CV
#  97.3333333333 support vectors 2321
# score on CV
#  97.3333333333 support vectors 2313
# score on CV
#  97.3333333333 support vectors 2304
# score on CV
#  97.3333333333 support vectors 2306
# score on CV
#  97.3333333333 support vectors 2313
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1825
# score on CV
#  96.3333333333 support vectors 2004
# score on CV
#  96.3333333333 support vectors 2151
# score on CV
#  97.0 support vectors 2210
# score on CV
#  97.0 support vectors 2251
# score on CV
#  97.3333333333 support vectors 2257
# score on CV
#  97.3333333333 support vectors 2277
# score on CV
#  97.3333333333 support vectors 2291
# score on CV
#  97.3333333333 support vectors 2295
# score on CV
#  97.3333333333 support vectors 2295
# score on CV
#  97.3333333333 support vectors 2294
# score on CV
#  97.3333333333 support vectors 2298
# score on CV
#  97.3333333333 support vectors 2309
# score on CV
#  97.3333333333 support vectors 2311
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1770
# score on CV
#  96.6666666667 support vectors 1970
# score on CV
#  97.3333333333 support vectors 2128
# score on CV
#  97.0 support vectors 2209
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1891
# score on CV
#  96.3333333333 support vectors 2071
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1799
# score on CV
#  96.6666666667 support vectors 1999
# score on CV
#  97.3333333333 support vectors 2144
# score on CV
#  97.0 support vectors 2230
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1779
# score on CV
#  96.6666666667 support vectors 1928
# score on CV
#  96.6666666667 support vectors 2114
# score on CV
#  97.0 support vectors 2176
# score on CV
#  97.0 support vectors 2215
# score on CV
#  97.0 support vectors 2279
# score on CV
#  97.0 support vectors 2281
# score on CV
#  97.0 support vectors 2302
# score on CV
#  97.0 support vectors 2304
# score on CV
#  97.0 support vectors 2301
# score on CV
#  97.0 support vectors 2310
# score on CV
#  97.0 support vectors 2317
# score on CV
#  97.0 support vectors 2315
# score on CV
#  97.0 support vectors 2321
# score on CV
#  97.0 support vectors 2309
# score on CV
#  97.0 support vectors 2312
# score on CV
#  97.0 support vectors 2305
# score on CV
#  97.0 support vectors 2297
# score on CV
#  97.0 support vectors 2297
# score on CV
#  97.0 support vectors 2295
# score on CV
#  97.0 support vectors 2301
# score on CV
#  97.0 support vectors 2296
# score on CV
#  97.0 support vectors 2288
# score on CV
#  97.3333333333 support vectors 2299
# score on CV
#  97.3333333333 support vectors 2299
# score on CV
#  97.3333333333 support vectors 2296
# score on CV
#  97.3333333333 support vectors 2297
# score on CV
#  97.3333333333 support vectors 2307
# score on CV
#  97.3333333333 support vectors 2307
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1854
# score on CV
#  96.6666666667 support vectors 2067
# score on CV
#  97.3333333333 support vectors 2173
# score on CV
#  97.0 support vectors 2232
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1815
# score on CV
#  97.0 support vectors 1968
# score on CV
#  97.0 support vectors 2102
# score on CV
#  97.0 support vectors 2187
# score on CV
#  97.0 support vectors 2232
# score on CV
#  97.0 support vectors 2267
# score on CV
#  97.3333333333 support vectors 2288
# score on CV
#  97.3333333333 support vectors 2284
# score on CV
#  97.3333333333 support vectors 2307
# score on CV
#  97.3333333333 support vectors 2300
# score on CV
#  97.3333333333 support vectors 2298
# score on CV
#  97.3333333333 support vectors 2293
# score on CV
#  97.3333333333 support vectors 2307
# score on CV
#  97.3333333333 support vectors 2321
# score on CV
#  97.3333333333 support vectors 2321
# score on CV
#  97.3333333333 support vectors 2326
# score on CV
#  97.3333333333 support vectors 2328
# score on CV
#  97.3333333333 support vectors 2323
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1844
# score on CV
#  96.3333333333 support vectors 2031
# score on CV
#  97.0 support vectors 2167
# score on CV
#  97.0 support vectors 2211
# score on CV
#  97.0 support vectors 2262
# score on CV
#  97.3333333333 support vectors 2281
# score on CV
#  97.3333333333 support vectors 2299
# score on CV
#  97.3333333333 support vectors 2310
# score on CV
#  97.3333333333 support vectors 2317
# score on CV
#  97.3333333333 support vectors 2315
# score on CV
#  97.3333333333 support vectors 2313
# score on CV
#  97.3333333333 support vectors 2316
# score on CV
#  97.3333333333 support vectors 2314
# score on CV
#  97.3333333333 support vectors 2319
# score on CV
#  97.3333333333 support vectors 2313
# score on CV
#  97.3333333333 support vectors 2319
# score on CV
#  97.3333333333 support vectors 2325
# score on CV
#  97.3333333333 support vectors 2328
# score on CV
#  97.3333333333 support vectors 2327
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1834
# score on CV
#  96.3333333333 support vectors 2009
# score on CV
#  97.0 support vectors 2165
# score on CV
#  97.0 support vectors 2225
# score on CV
#  97.0 support vectors 2242
# score on CV
#  97.0 support vectors 2266
# score on CV
#  97.0 support vectors 2278
# score on CV
#  97.0 support vectors 2278
# score on CV
#  97.0 support vectors 2286
# score on CV
#  97.0 support vectors 2283
# score on CV
#  97.0 support vectors 2292
# score on CV
#  97.0 support vectors 2293
# score on CV
#  97.0 support vectors 2296
# score on CV
#  97.0 support vectors 2293
# score on CV
#  97.0 support vectors 2289
# score on CV
#  97.0 support vectors 2286
# score on CV
#  97.0 support vectors 2282
# score on CV
#  97.0 support vectors 2280
# score on CV
#  97.0 support vectors 2287
# score on CV
#  97.0 support vectors 2290
# score on CV
#  97.0 support vectors 2294
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1819
# score on CV
#  96.6666666667 support vectors 1985
# score on CV
#  96.6666666667 support vectors 2141
# score on CV
#  97.0 support vectors 2233
# score on CV
#  97.0 support vectors 2259
# score on CV
#  97.0 support vectors 2262
# score on CV
#  97.0 support vectors 2270
# score on CV
#  97.3333333333 support vectors 2288
# score on CV
#  97.0 support vectors 2293
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1842
# score on CV
#  96.6666666667 support vectors 2007
# score on CV
#  97.0 support vectors 2157
# score on CV
#  97.0 support vectors 2219
# score on CV
#  97.0 support vectors 2234
# score on CV
#  97.0 support vectors 2259
# score on CV
#  97.0 support vectors 2266
# score on CV
#  97.0 support vectors 2270
# score on CV
#  97.0 support vectors 2281
# score on CV
#  97.0 support vectors 2275
# score on CV
#  97.0 support vectors 2273
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1775
# score on CV
#  96.6666666667 support vectors 1946
# score on CV
#  97.3333333333 support vectors 2138
# score on CV
#  97.0 support vectors 2225
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1775
# score on CV
#  96.6666666667 support vectors 1937
# score on CV
#  96.6666666667 support vectors 2129
# score on CV
#  96.6666666667 support vectors 2199
# score on CV
#  97.0 support vectors 2260
# score on CV
#  97.3333333333 support vectors 2290
# score on CV
#  97.0 support vectors 2284
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1787
# score on CV
#  96.6666666667 support vectors 1951
# score on CV
#  97.0 support vectors 2094
# score on CV
#  97.0 support vectors 2197
# score on CV
#  97.0 support vectors 2232
# score on CV
#  97.0 support vectors 2259
# score on CV
#  97.0 support vectors 2270
# score on CV
#  97.0 support vectors 2286
# score on CV
#  97.0 support vectors 2284
# score on CV
#  97.0 support vectors 2285
# score on CV
#  97.0 support vectors 2284
# score on CV
#  97.0 support vectors 2296
# score on CV
#  97.0 support vectors 2297
# score on CV
#  97.0 support vectors 2305
# score on CV
#  97.0 support vectors 2308
# score on CV
#  97.3333333333 support vectors 2317
# score on CV
#  97.3333333333 support vectors 2313
# score on CV
#  97.0 support vectors 2317
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1834
# score on CV
#  96.3333333333 support vectors 2026
# score on CV
#  97.0 support vectors 2171
# score on CV
#  96.6666666667 support vectors 2196
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1792
# score on CV
#  96.6666666667 support vectors 1954
# score on CV
#  96.6666666667 support vectors 2112
# score on CV
#  97.3333333333 support vectors 2172
# score on CV
#  97.3333333333 support vectors 2234
# score on CV
#  97.6666666667 support vectors 2265
# score on CV
#  97.3333333333 support vectors 2278
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1842
# score on CV
#  96.3333333333 support vectors 2028
# score on CV
#  97.0 support vectors 2157
# score on CV
#  97.0 support vectors 2202
# score on CV
#  97.0 support vectors 2230
# score on CV
#  97.0 support vectors 2266
# score on CV
#  97.0 support vectors 2273
# score on CV
#  97.0 support vectors 2278
# score on CV
#  97.0 support vectors 2286
# score on CV
#  97.0 support vectors 2298
# score on CV
#  97.0 support vectors 2285
# score on CV
#  97.0 support vectors 2305
# score on CV
#  97.0 support vectors 2302
# score on CV
#  97.0 support vectors 2297
# score on CV
#  97.0 support vectors 2298
# score on CV
#  97.0 support vectors 2300
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1746
# score on CV
#  97.0 support vectors 1921
# score on CV
#  97.0 support vectors 2084
# score on CV
#  97.3333333333 support vectors 2176
# score on CV
#  97.0 support vectors 2217
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1840
# score on CV
#  96.3333333333 support vectors 2024
# score on CV
#  97.0 support vectors 2176
# score on CV
#  97.0 support vectors 2196
# score on CV
#  97.0 support vectors 2253
# score on CV
#  97.0 support vectors 2255
# score on CV
#  97.0 support vectors 2268
# score on CV
#  97.0 support vectors 2292
# score on CV
#  97.0 support vectors 2297
# score on CV
#  97.0 support vectors 2311
# score on CV
#  97.0 support vectors 2320
# score on CV
#  97.0 support vectors 2325
# score on CV
#  97.0 support vectors 2328
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1884
# score on CV
#  96.3333333333 support vectors 2047
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1908
# score on CV
#  96.6666666667 support vectors 2093
# score on CV
#  97.3333333333 support vectors 2194
# score on CV
#  97.0 support vectors 2258
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1798
# score on CV
#  96.6666666667 support vectors 1945
# score on CV
#  96.6666666667 support vectors 2113
# score on CV
#  97.0 support vectors 2200
# score on CV
#  97.3333333333 support vectors 2254
# score on CV
#  97.3333333333 support vectors 2272
# score on CV
#  97.3333333333 support vectors 2270
# score on CV
#  97.3333333333 support vectors 2293
# score on CV
#  97.3333333333 support vectors 2320
# score on CV
#  97.3333333333 support vectors 2327
# score on CV
#  97.3333333333 support vectors 2332
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1813
# score on CV
#  96.6666666667 support vectors 2005
# score on CV
#  97.0 support vectors 2155
# score on CV
#  96.6666666667 support vectors 2210
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1905
# score on CV
#  96.6666666667 support vectors 2073
# score on CV
#  97.3333333333 support vectors 2178
# score on CV
#  97.0 support vectors 2231
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1829
# score on CV
#  96.3333333333 support vectors 2006
# score on CV
#  96.6666666667 support vectors 2147
# score on CV
# ...
#  97.0 support vectors 2166
# score on CV
#  97.0 support vectors 2191
# score on CV
#  97.0 support vectors 2235
# score on CV
#  97.3333333333 support vectors 2252
# score on CV
#  97.3333333333 support vectors 2285
# score on CV
#  97.3333333333 support vectors 2298
# score on CV
#  97.3333333333 support vectors 2310
# score on CV
#  97.3333333333 support vectors 2306
# score on CV
#  97.3333333333 support vectors 2315
# score on CV
#  97.0 support vectors 2300
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1820
# score on CV
#  96.6666666667 support vectors 1978
# score on CV
#  96.6666666667 support vectors 2137
# score on CV
#  97.0 support vectors 2215
# score on CV
#  97.0 support vectors 2244
# score on CV
#  97.0 support vectors 2269
# score on CV
#  97.0 support vectors 2295
# score on CV
#  97.0 support vectors 2300
# score on CV
#  97.0 support vectors 2314
# score on CV
#  97.0 support vectors 2305
# score on CV
#  97.0 support vectors 2317
# score on CV
#  97.0 support vectors 2316
# score on CV
#  97.0 support vectors 2322
# score on CV
#  97.0 support vectors 2325
# score on CV
#  97.0 support vectors 2328
# score on CV
#  97.0 support vectors 2328
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  95.6666666667 support vectors 1807
# score on CV
#  96.6666666667 support vectors 1999
# score on CV
#  97.0 support vectors 2130
# score on CV
#  97.0 support vectors 2187
# score on CV
#  97.0 support vectors 2221
# score on CV
#  97.0 support vectors 2264
# score on CV
#  97.0 support vectors 2260
# score on CV
#  97.0 support vectors 2269
# score on CV
#  97.0 support vectors 2280
# score on CV
#  97.0 support vectors 2282
# score on CV
#  97.0 support vectors 2285
# score on CV
#  97.0 support vectors 2285
# score on CV
#  97.0 support vectors 2287
# score on CV
#  97.0 support vectors 2290
# score on CV
#  97.0 support vectors 2290
# score on CV
#  97.0 support vectors 2288
# score on CV
#  97.0 support vectors 2291
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1799
# score on CV
#  96.6666666667 support vectors 2005
# score on CV
#  96.6666666667 support vectors 2156
# score on CV
#  96.6666666667 support vectors 2202
# score on CV
#  97.0 support vectors 2225
# score on CV
#  97.0 support vectors 2245
# score on CV
#  97.0 support vectors 2248
# score on CV
#  97.0 support vectors 2293
# score on CV
#  97.0 support vectors 2295
# score on CV
#  97.0 support vectors 2297
# score on CV
#  97.0 support vectors 2298
# score on CV
#  97.0 support vectors 2303
# score on CV
#  97.0 support vectors 2308
# score on CV
#  97.0 support vectors 2306
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1893
# score on CV
#  96.6666666667 support vectors 2070
# score on CV
#  97.3333333333 support vectors 2193
# score on CV
#  97.0 support vectors 2228
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1855
# score on CV
#  96.6666666667 support vectors 2039
# score on CV
#  97.3333333333 support vectors 2159
# score on CV
#  97.0 support vectors 2225
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1779
# score on CV
#  96.6666666667 support vectors 1941
# score on CV
#  96.6666666667 support vectors 2120
# score on CV
#  97.0 support vectors 2224
# score on CV
#  97.0 support vectors 2257
# score on CV
#  97.0 support vectors 2272
# score on CV
#  97.0 support vectors 2284
# score on CV
#  97.0 support vectors 2308
# score on CV
#  97.0 support vectors 2323
# score on CV
#  97.0 support vectors 2314
# score on CV
#  97.0 support vectors 2315
# score on CV
#  97.0 support vectors 2308
# score on CV
#  97.0 support vectors 2314
# score on CV
#  97.0 support vectors 2299
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1853
# score on CV
#  96.3333333333 support vectors 2037
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1800
# score on CV
#  96.6666666667 support vectors 1998
# score on CV
#  97.0 support vectors 2145
# score on CV
#  97.0 support vectors 2208
# score on CV
#  97.0 support vectors 2254
# score on CV
#  97.0 support vectors 2294
# score on CV
#  97.3333333333 support vectors 2294
# score on CV
#  97.3333333333 support vectors 2296
# score on CV
#  97.3333333333 support vectors 2319
# score on CV
#  97.3333333333 support vectors 2321
# score on CV
#  97.3333333333 support vectors 2317
# score on CV
#  97.3333333333 support vectors 2330
# score on CV
#  97.3333333333 support vectors 2328
# score on CV
#  97.3333333333 support vectors 2327
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1892
# score on CV
#  96.6666666667 support vectors 2061
# score on CV
#  97.0 support vectors 2150
# score on CV
#  97.0 support vectors 2219
# score on CV
#  97.0 support vectors 2273
# score on CV
#  97.3333333333 support vectors 2285
# score on CV
#  97.3333333333 support vectors 2295
# score on CV
#  97.3333333333 support vectors 2312
# score on CV
#  97.3333333333 support vectors 2314
# score on CV
#  97.3333333333 support vectors 2318
# score on CV
#  97.3333333333 support vectors 2311
# score on CV
#  97.3333333333 support vectors 2319
# score on CV
#  97.3333333333 support vectors 2317
# score on CV
#  97.3333333333 support vectors 2318
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1892
# score on CV
#  96.3333333333 support vectors 2053
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1886
# score on CV
#  96.6666666667 support vectors 2083
# score on CV
#  97.3333333333 support vectors 2195
# score on CV
#  97.3333333333 support vectors 2239
# score on CV
#  97.3333333333 support vectors 2261
# score on CV
#  97.3333333333 support vectors 2248
# score on CV
#  97.3333333333 support vectors 2251
# score on CV
#  97.6666666667 support vectors 2281
# score on CV
#  97.6666666667 support vectors 2296
# score on CV
#  97.6666666667 support vectors 2294
# score on CV
#  97.6666666667 support vectors 2296
# score on CV
#  97.6666666667 support vectors 2296
# score on CV
#  97.3333333333 support vectors 2297
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1837
# score on CV
#  96.3333333333 support vectors 2014
# score on CV
#  97.0 support vectors 2180
# score on CV
#  97.0 support vectors 2215
# score on CV
#  97.0 support vectors 2250
# score on CV
#  97.0 support vectors 2264
# score on CV
#  97.0 support vectors 2279
# score on CV
#  97.0 support vectors 2290
# score on CV
#  97.0 support vectors 2295
# score on CV
#  97.0 support vectors 2299
# score on CV
#  97.0 support vectors 2312
# score on CV
#  97.0 support vectors 2311
# score on CV
#  97.0 support vectors 2309
# score on CV
#  97.0 support vectors 2308
# score on CV
#  97.0 support vectors 2302
# score on CV
#  97.0 support vectors 2305
# score on CV
#  97.0 support vectors 2316
# score on CV
#  97.0 support vectors 2313
# score on CV
#  97.0 support vectors 2311
# score on CV
#  97.0 support vectors 2309
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1799
# score on CV
#  96.6666666667 support vectors 1998
# score on CV
#  97.0 support vectors 2159
# score on CV
#  96.6666666667 support vectors 2219
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1843
# score on CV
#  96.3333333333 support vectors 2026
# score on CV
#  97.0 support vectors 2177
# score on CV
#  96.6666666667 support vectors 2219
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1809
# score on CV
#  96.6666666667 support vectors 1979
# score on CV
#  97.0 support vectors 2138
# score on CV
#  96.6666666667 support vectors 2213
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1838
# score on CV
#  96.6666666667 support vectors 2007
# score on CV
#  97.3333333333 support vectors 2162
# score on CV
#  97.0 support vectors 2208
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1818
# score on CV
#  97.0 support vectors 1970
# score on CV
#  97.0 support vectors 2092
# score on CV
#  97.3333333333 support vectors 2191
# score on CV
#  97.0 support vectors 2256
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1822
# score on CV
#  97.0 support vectors 2022
# score on CV
#  96.6666666667 support vectors 2144
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.6666666667 support vectors 1809
# score on CV
#  96.6666666667 support vectors 1995
# score on CV
#  97.0 support vectors 2141
# score on CV
#  96.6666666667 support vectors 2216
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1835
# score on CV
#  96.6666666667 support vectors 2020
# score on CV
#  96.6666666667 support vectors 2165
# score on CV
#  96.6666666667 support vectors 2214
# score on CV
#  97.3333333333 support vectors 2254
# score on CV
#  97.0 support vectors 2272
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1791
# score on CV
#  96.6666666667 support vectors 1968
# score on CV
#  97.0 support vectors 2138
# score on CV
#  97.0 support vectors 2210
# score on CV
#  97.0 support vectors 2257
# score on CV
#  97.0 support vectors 2275
# score on CV
#  97.0 support vectors 2283
# score on CV
#  97.0 support vectors 2290
# score on CV
#  97.0 support vectors 2292
# score on CV
#  97.3333333333 support vectors 2292
# score on CV
#  97.3333333333 support vectors 2299
# score on CV
#  97.3333333333 support vectors 2299
# score on CV
#  97.3333333333 support vectors 2304
# score on CV
#  97.3333333333 support vectors 2311
# score on CV
#  97.3333333333 support vectors 2300
# score on CV
#  97.3333333333 support vectors 2312
# score on CV
#  97.3333333333 support vectors 2315
# score on CV
#  97.3333333333 support vectors 2311
# score on CV
#  97.3333333333 support vectors 2310
# score on CV
#  97.3333333333 support vectors 2316
# score on CV
#  97.3333333333 support vectors 2314
# score on CV
#  97.3333333333 support vectors 2313
# score on CV
#  97.3333333333 support vectors 2315
# score on CV
#  97.3333333333 support vectors 2315
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1846
# score on CV
#  96.6666666667 support vectors 2057
# score on CV
#  97.3333333333 support vectors 2174
# score on CV
#  97.0 support vectors 2211
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1826
# score on CV
#  96.3333333333 support vectors 2004
# score on CV
#  96.6666666667 support vectors 2138
# score on CV
#  97.0 support vectors 2172
# score on CV
#  97.0 support vectors 2212
# score on CV
#  97.0 support vectors 2247
# score on CV
#  97.0 support vectors 2271
# score on CV
#  97.0 support vectors 2279
# score on CV
#  97.0 support vectors 2283
# score on CV
#  97.0 support vectors 2284
# score on CV
#  97.0 support vectors 2286
# score on CV
#  97.0 support vectors 2293
# score on CV
#  97.0 support vectors 2302
# score on CV
#  97.0 support vectors 2309
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1792
# score on CV
#  96.6666666667 support vectors 1945
# score on CV
#  97.0 support vectors 2133
# score on CV
#  96.6666666667 support vectors 2197
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1825
# score on CV
#  96.6666666667 support vectors 1998
# score on CV
#  96.6666666667 support vectors 2147
# score on CV
#  97.0 support vectors 2194
# score on CV
#  97.3333333333 support vectors 2218
# score on CV
#  97.3333333333 support vectors 2256
# score on CV
#  97.3333333333 support vectors 2271
# score on CV
#  97.3333333333 support vectors 2287
# score on CV
#  97.3333333333 support vectors 2287
# score on CV
#  97.3333333333 support vectors 2288
# score on CV
#  97.3333333333 support vectors 2290
# score on CV
#  97.0 support vectors 2276
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1830
# score on CV
#  96.6666666667 support vectors 2027
# score on CV
#  96.6666666667 support vectors 2144
# score on CV
#  97.0 support vectors 2194
# score on CV
#  97.0 support vectors 2228
# score on CV
#  97.3333333333 support vectors 2234
# score on CV
#  97.3333333333 support vectors 2281
# score on CV
#  97.3333333333 support vectors 2292
# score on CV
#  97.3333333333 support vectors 2322
# score on CV
#  97.3333333333 support vectors 2322
# score on CV
#  97.3333333333 support vectors 2321
# score on CV
#  97.3333333333 support vectors 2324
# score on CV
#  97.3333333333 support vectors 2314
# score on CV
#  97.3333333333 support vectors 2311
# score on CV
#  97.0 support vectors 2327
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.0 support vectors 1787
# score on CV
#  96.6666666667 support vectors 1990
# score on CV
#  96.6666666667 support vectors 2134
# score on CV
#  97.0 support vectors 2221
# score on CV
#  97.3333333333 support vectors 2239
# score on CV
#  97.0 support vectors 2254
# breaking out
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1844
# score on CV
#  96.3333333333 support vectors 2027
# score on CV
#  97.0 support vectors 2170
# score on CV
#  97.0 support vectors 2218
# score on CV
#  97.0 support vectors 2259
# score on CV
#  97.3333333333 support vectors 2275
# score on CV
#  97.3333333333 support vectors 2291
# score on CV
#  97.3333333333 support vectors 2292
# score on CV
#  97.3333333333 support vectors 2312
# score on CV
#  97.3333333333 support vectors 2314
# score on CV
#  97.3333333333 support vectors 2318
# score on CV
#  97.3333333333 support vectors 2317
# score on CV
#  97.3333333333 support vectors 2321
# --------------------
# score on CV
#  95.3333333333 support vectors 477
# score on CV
#  96.3333333333 support vectors 1838
# score on CV
#  96.6666666667 support vectors 1996
# score on CV
#  96.6666666667 support vectors 2130
# score on CV
#  97.0 support vectors 2198
# score on CV
#  97.0 support vectors 2225
# score on CV
#  97.0 support vectors 2261
# score on CV
#  97.0 support vectors 2282
# score on CV
#  97.0 support vectors 2289
# score on CV
#  97.0 support vectors 2300
# score on CV
#  97.0 support vectors 2298
# score on CV
#  97.0 support vectors 2306
# score on CV
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-21410b16b40b> in <module>()
#      13     past_c, past_acc = 0., 0.
#      14     while fu == False:
# ---> 15         [A,B,C, acc, fu] = laundromat(clf, A, B, C, acc, PCUT = 0.99)
#      16         if past_c == C.shape[0] and past_acc == acc:
#      17             fu = True
#
# <ipython-input-18-cc9f4ef0562f> in laundromat(model, X, Y, XUniverse, max_acc, PCUT)
#       1 def laundromat(model, X, Y, XUniverse, max_acc, PCUT = 0.95):
#       2     # train
# ----> 3     model.fit(X, Y)
#       4
#       5     # evaluate
#
# //anaconda/python.app/Contents/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     176
#     177         seed = rnd.randint(np.iinfo('i').max)
# --> 178         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     179         # see comment on the other call to np.iinfo in this file
#     180
#
# //anaconda/python.app/Contents/lib/python2.7/site-packages/sklearn/svm/base.pyc in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     231                 cache_size=self.cache_size, coef0=self.coef0,
#     232                 gamma=self._gamma, epsilon=self.epsilon,
# --> 233                 max_iter=self.max_iter, random_seed=random_seed)
#     234
#     235         self._warn_from_fit_status()
#
# KeyboardInterrupt:
#  97.0 support vectors 2307

# %%
print 'accuracy', acc
print 'support v', clf.support_vectors_.shape[0]
print 'A', A.shape
print 'B', B.shape
print 'C', C.shape

# %% [markdown]
# #### SVM on new training set

# %%
clf_svm = svm.SVC(kernel='rbf', cache_size=1000, probability=True, C=10000000, gamma = 0.275)
clf_svm.fit(A, B)

# %% [markdown]
# #### NN on new training set

# %%
from Neurotic import *
def neuracc(thetas, x, y):
    tot = y.shape[0]
    count = 0.0
    for i, truth in enumerate(y):
        sol = h(thetas, layers, x[i])
        if np.argmax(sol)== truth:
            count +=1.
    return 100.*count/tot

def optimizeThetas(tinit, layers, x, y, lam, visual=True):
    def f(w):
        return j(w, layers, x, y, lam)
    def fprime(w):
        return v(w, layers, x, y, lam)
    
    [thetas, f, d] = fmin_l_bfgs_b(func=f, x0=tinit, fprime=fprime, maxiter=1000)
    if visual:
        print thetas[0:10]
        print f
        print d
    return thetas

# %%
M, nodes = A.shape
Y3 = np.atleast_2d(B).T

layers = [2*nodes, nodes, 2]
tinit = np.hstack([randomize_thetas(2*nodes,nodes).flatten(), 
                   randomize_thetas(nodes,2*nodes).flatten(),
                   randomize_thetas(2,nodes).flatten()])


opt_score, opt_lala, opt_ot = 0.0, 0.0, None
#for lala in [0.000001, 0.00001, 0.0001, 0.001]:
for lala in [1e-05]:
    ot = optimizeThetas(tinit, layers, A, Y3, lala)
    new_acc = neuracc(ot, X_CV, Y_CV)
    print 'lala', lala, new_acc
    if new_acc > opt_score:
        opt_score = new_acc
        opt_lala = lala
        opt_ot = ot

print '_______________BEST SCORE:', opt_score
print 'best lambda:', opt_lala

# %%
opt_lala

# %% [markdown]
# #### Mix SVM & NN and evaluate on cross validation set

# %%
## NN
NN = np.zeros((limit_cv, 2))
for i, record in enumerate(X_CV):
    NN[i,0] = np.argmax(h(opt_ot, layers, record))
    NN[i,1] = np.max(h(opt_ot, layers, record))

# from previous and last SVM
a = clf_svm.predict(X_CV)
b = clf_svm.predict_proba(X_CV)

count = 0.0
different = 0
changed_from_svm_to_nn = 0
to_sumbit = np.zeros((limit_cv,2))
to_compare = np.zeros((limit_cv,))
for i in range(limit_cv):
    p = int(a[i])
    nn = int(NN[i,0])
    if p!=nn:
        different += 1
        if b[i, p]<NN[i,1]:
            print 'Y (' + `Y_CV[i]` + ') SVM (' + `p` + ') NN (' + `nn` + ')'
            print 'changed_from_svm_to_nn', b[i, p], NN[i,1]
            changed_from_svm_to_nn += 1
            p = nn
        else:
            print '____Y (' + `Y_CV[i]` + ') SVM (' + `p` + ') NN (' + `nn` + ')'
            print '____kept_svm_instead_of_nn', b[i, p], NN[i,1]
    if int(p)==Y_CV[i]:
        count +=1
    to_compare[i] = p
    
print 'acc', 100.*count/limit_cv
print 'svm and NN differ', different
print 'changed_from_svm_to_nn', changed_from_svm_to_nn

# %%
# as compared to simple SVM
from sklearn.metrics import *  
print(classification_report(Y_CV, a))

# %%
# how it does with mix and match
print(classification_report(Y_CV, to_compare))

# %% [markdown]
# #### SVM & NN on all training data (included CV)

# %%
XX = np.vstack([X_CV, A])
YY = np.hstack([Y_CV, B])

# %%
final_svm = svm.SVC(kernel='rbf', cache_size=1000, probability=True, C=10000000, gamma = 0.3)
final_svm.fit(XX, YY)

# %%
M, nodes = XX.shape
Y3 = np.atleast_2d(YY).T

layers = [2*nodes, nodes, 2]
tinit = np.hstack([randomize_thetas(2*nodes,nodes).flatten(), 
                   randomize_thetas(nodes,2*nodes).flatten(),
                   randomize_thetas(2,nodes).flatten()])

final_ot = optimizeThetas(tinit, layers, XX, Y3, 0.00001)

# %%
print final_svm.support_vectors_.shape[0]
print XX.shape

# %% [markdown]
# #### Predict Test Set

# %%
x_test = x_all[1000:, :]

## NN
NN = np.zeros((9000, 2))
for i, record in enumerate(x_test):
    NN[i,0] = np.argmax(h(final_ot, layers, record))
    NN[i,1] = np.max(h(final_ot, layers, record))

# from previous and last SVM
a = final_svm.predict(x_test)
b = final_svm.predict_proba(x_test)

to_submit_nn = np.zeros((9000,2))
to_submit_svm_nn = np.zeros((9000,2))
to_submit_svm = np.zeros((9000,2))

different = 0
changed_from_svm_to_nn = 0
for i in range(9000):
    p = int(a[i])
    to_submit_svm[i,0] = i+1
    to_submit_svm[i,1] = p

    nn = int(NN[i,0])
    if p!=nn:
        different += 1
        if b[i, p]<NN[i,1]:
            print 'SVM (' + `p` + ') NN (' + `nn` + ')'
            print 'changed_from_svm_to_nn', b[i, p], NN[i,1]
            changed_from_svm_to_nn += 1
            p = nn
        else:
            print '____ SVM (' + `p` + ') NN (' + `nn` + ')'
            print '____ kept_svm_instead_of_nn', b[i, p], NN[i,1]    
    to_submit_nn[i,0] = i+1
    to_submit_nn[i,1] = nn
    to_submit_svm_nn[i,0] = i+1
    to_submit_svm_nn[i,1] = p
    
print 'svm and NN differ', different
print 'changed_from_svm_to_nn', changed_from_svm_to_nn

# %% [markdown]
# #### SAVING TEST PREDICTIONS

# %%
print 'To submitt add header: Id,Solution'
print to_submit_svm[0:10,:]
np.savetxt('./predictions_play_tuesday_svm2.csv', to_submit_svm, fmt='%i,%i')

# %%
print 'To submitt add header: Id,Solution'
print to_submit_nn[0:10,:]
np.savetxt('./predictions_play_tuesday_nn2.csv', to_submit_nn, fmt='%i,%i')

# %%
print 'To submitt add header: Id,Solution'
print to_submit_svm_nn[0:10,:]
np.savetxt('./predictions_play_tuesday_mix2.csv', to_submit_svm_nn, fmt='%i,%i')
